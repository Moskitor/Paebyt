# %% [markdown]
# <a href="https://colab.research.google.com/github/Moskitor/Paebyt/blob/main/OPISU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ![Picture](https://drive.google.com/uc?export=view&id=1tR2tGdwFwyCmr4c7-roYIjRNpPxuSiSz)
# <h1 align= Center> ORGANISMO PROVINCIAL DE INTEGRACIÓN SOCIAL Y URBANA </h1>
#
# ## <center> Niveles de Integración Socio-Urbana en barrios y asentamientos de la Provincia de Buenos Aires (OPISU) </center>
# ### <center> Exploracion de datos (EDA: Exploratory Data Analysis) </center>
#
# ---
#
# En este cuaderno simularemos algunos datos de algunas variables posibles a ser utilizadas para construir algunos indicadores y realizaremos Algun analisis de exploracion de datos - **completar**
# <br>
# <br>
#
# **Indice**
# 1. [Definicion del problema](#1)
# 2. [Datos](#2)
# 3. [Evaluacion](#3)
# 4. [Variables e indicadores](#4)
# 5. [Analisis Exploratorio de datos](#5)
# 6. [Proximos pasos](#6)

# %% [markdown]
# <a name="1"></a>
#
# ## 1. Definición del problema
#
# Dados unos determinados  parametros de los proyectos, los barrios y las personas, ¿se puede predecir si los proyectos redundan en un mayor nivel de integración socio urbana?

# %% [markdown]
# <a name="2"></a>
#
# ## 2. Datos
#
# Los datos originales debieran proceder de la base de datos de OPISU. Como asi tambien hay bases de datos de diferentes organismos o, en caso de no poseerlos, serán producidos por el OPISU.
# <br>
# Para el presente preproyecto y al no contar con datos reales se crearan datos ficticios (fake data) siguiendo distintas distribuciones para la generacion de los mismos. <br>
#
# Para cada variable se especificara que metodo de generacion de datos ficticios se utilizara **completar**

# %% [markdown]
# <a name="3"></a>
# ## 3. Evaluación
#
# Si se puede predecir, en esta prueba de concepto con una exactitud del 75% si un barrio es impactado positivamente por los diferentes proyectos entonces se avanzara en el proyecto

# %% [markdown]
# <a name="4"></a>
# ## 4. Variables e indicadores
#
# ### a. Indicador de integración urbano-ambiental
#
# <br>
#
# * Dimensión Urbana:
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
# |Accesibilidad (rampas en la vía pública) | **IU_Acce**  |
# |Agua| **IU_Agua**  |
# |Cloacas| **IU_Cloa** |
# |Corredores seguros|**IU_Corr_segu**|
# |Electricidad| **IU_Elec**|
# |Existencia de espacio público | **IU_Espa_Pub**|
# |Existencia de transporte público| **IU_Tran_Pub**|
# |Pavimentación de calles| **IU_Nivl_Pavi**|
# |(conexión vial, int. a la cuadrícula urbana) Continuidad vial
# |Saneamiento hidráulico|**IU_Sane_Urba**|
# |Señalización de la vía pública y Forestación|**IU_Sena_y_fore**|
# |Transitabilidad de la vía publica|**IU_Tran**|
# |Viviendas mejoradas: ambientes | **IU_Vivi_Mejo_Ambi** |
# |Viviendas mejoradas: características constructivas, problemas|**IU_Vivi_Mejo_Pblm**
#
# <br>
#
# * Dimensión Ambiental:
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
# |Alumbrado público |Am_ |
# |Desbordes cloacales|Am_ |
# |Existencia de basurales|Am_ |
# |Existencia de m2 de espacio verde por habitante|Am_ |
# |Inundaciones|Am_ |
# |Olores fuertes|Am_ |
# |Recolección de residuos|Am_ |
#
# <br>
#
# * Dimensión Regularización dominial:
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
# |Cantidad de documentación entregada que legalice la tenencia|RD_ |
# | (escrituras o similiar como máx nivel de avance)|
# |Cantidad de Planos catastrales| RD_ |
# |(proporción del total de cada barrio)|
# |Cantidad Estudio de título y catastro | RD_ |
# |(proporción del total de cada barrio) |
# |Escrituras o similiar | RD_ |
# |(como máximo nivel de avance)|
# |Mujeres como titulares/cotitulares| RD_|
# |Parcelas/lotes beneficiadas con incremento en la seguridad de la tenencia| RD_|
# |Personas/familias beneficiadas con incremento en la seguridad de la tenencia| RD_ |
# |Personas/familias contactadas para iniciar trámite de regularización dominial| RD_ |
# |Relación con la vivienda| RD_ |
# |Trámite iniciado en etapa avanzada| RD_ |
# |Trámites efectivamente iniciados| RD_ |
#
# <br>
#
# * Dimensión sustentabilidad/precio del suelo:
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
# |Precio de mercado de las viviendas del barrio| PS_ |
# |Precio de mercado del m2 de vivienda en las inmediaciones del barrio| PS_ |
# |Precio de mercado informal de las viviendas del barrio| PS_ |
# |Valuación fiscal de las viviendas del barrio| PS_ |
# |Valuación fiscal de las viviendas en las inmediaciones del barrio| PS_ |
# |Valuación fiscal de los inmuebles del barrio finalizado el proceso| PS_ |
#
# <br>
#
# * Dimensión Seguridad ciudadana:
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
# |Denuncias| SC_|
# |Homicidos en ocasión de robo| SC_|
# |Sensación de seguridad de miembros del hogar| SC_|
# |Victimización de familiares y/o vecinos en los últimos 3 meses| SC_|
# |Victimización de miembros del hogar en el último año| SC_|
# |Victimización en los últimos 3 meses/último año| SC_|
#
# <br>
#
# ### b. Indicador de integración social
#
# <br>
#
# * Dimensión Participación Ciudadana
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
# |Personas participantes en proceso de evaluación y seguimiento de aspectos puntuales| PC_|
# |Personas participantes en proceso de validación de los proyectos| PC_|
# |Personas participantes en reuniones informativas| PC_|
#
# <br>
#
# * Dimensión Salud y acceso al servicio de salud
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
# |Acceso a los medicamentos| S_|
# |Cobertura de salud| S_|
# |Embarazo adolescente| S_|
# |Embarazo y controles durante el embarazo| S_|
# |Existencia de centro de salud| S_|
# |Personas con enfermedad aguda/Enfermedades y afecciones| S_|
# |Visitas al médico en los últimos 3 meses| S_|
#
# <br>
#
# * Dimensión Educación y acceso al servicio educativo
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
# |Máximo nivel educativo alcanzado| Ed_ |
# |Motivos de deserción escolar| Ed_ |
# |Nivel de alfabetización| Ed_ |
# |Personas en edad escolar que asisten a establecimientos escolares| Ed_ |
#
# <br>
#
# * Dimensión Seguridad alimentaria y asistencia directa
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
# |Acceso gratuito a bienes y servicios (persona)|SA_ |
# |Acceso gratuito a bienes y servicios (Hogar/vivienda)|SA_ |
# |Acceso a viandas de comedor|SA_ |
# |Concurrencia a comedor|SA_ |
#
# <br>
#
# * Dimensión acceso a Programas Sociales
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
# |Acceso a programas sociales|PS_ |
#
# <br>
#
# * Dimensión Transporte y comunicación
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
# |Medios de transporte empleados|TC_ |
#
#
# ### c. Indicador de integración productiva/económica
#
# <br>
#
# * Dimensión Económica
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
# |Apoyo al empleo (cooperativas)| EC_ |
# |Conformación de circuitos comerciales o mercados| EC_ |
# |Estrategias e ingresos del hogar| EC_ |
# |Existencia de comercios y/o emprendimientos productivos| EC_ |
# |Existencia de nuevos comercios y/o nuevos emprendimientos productivos| EC_ |
# |Fortalecimiento de redes comerciales| EC_ |
# |Generación de empleo, nuevos puestos de trabajo ocupados por mujeres| EC_ |
# |Ingresos de los individuos y del hogar| EC_ |
# |Ingresos por AUH| EC_ |
# |No acceso a AUH| EC_ |
#
# <br>
#
# * Dimensión Formalización
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
#   |Trabajo y ocupación| Fo_ |
#   |Apertura de cuentas a comercios, por barrio, por partido| Fo_ |
#   |Apertura de cuentas a cooperativas y otras UP de la EPSS, por barrio, por partido| Fo_ |
#   |Apertura de cuentas a trabajadores de la EPSS, por barrio, por partido| Fo_ |
# |Efectorización (monotributo social) de trabajadores/as, por barrio| Fo_ |
#   |Exención en Ingresos Brutos para cooperativas y trabajadores/as, por barrio| Fo_ |
#   |Inscripción en Ingresos Brutos de cooperativas y trabajadores/as, por barrio| Fo_ |
#   |Nivel de facturación de comercios barriales, por barrio| Fo_ |
#   |Nivel de facturación de cooperativas barriales, por barrio| Fo_ |
#   |Nuevos cuit de cooperativas y otras UP de la EPSS, por barrio| Fo_ |
#
# * Dimensión Laboral
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
#   |Datos del mercado de trabajo para jóvenes y mujeres| La_ |
#   |Empleo: PEA, Tasas de empleo, desempleo y actividad| La_ |
#   |Generación de empleo, nuevos puestos de trabajo generados| La_ |
#   |Generación de empleo, nuevos puestos de trabajo ocupados por vecinos/as| La_ |
#   |Subocupación y precarización laboral| La_ |
#
# <br>
#
# * Dimensión Productiva
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
#   |Cantidad de cooperativas y federaciones| Pr_ |
#   |Cooperativas, otras UP, y trabajadores de la EPSS| Pr_ |
# | Licitaciones, obras y servicios ejecutados por cooperativas y otras UP de la EPSS| Pr_ |
#   |Unidades productivas proveedores de la PBA| Pr_ |
#
# <br>
#
# * Dimensión Socioeconómica
#
# <br>
#
# |       Nombre                            | Variable    |
# |:-----------------------------------------|:------------|
#    |Incidencia de espacios productivos y comerciales dentro del hogar1| So_ |
#    |Niveles de pobreza e indigencia1| So_ |
#    |Ocupaciones laborales y participación de la EPSS1| So_ |
#    |Perfil económico, empresarial y laboral de la región1| So_ |

# %% [markdown]
# <a name="5"></a>
# ## Analisis exploratorio de datos (EDA: Exploratory Data Analysis)

# %% [markdown]
# ####  importacion de librerias

# %%
# Regular EDA (exploratory data analysis) and plotting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# para visualizar los graficos dentro del notebook
# %matplotlib inline 
# Random seeds (para reproducir datos)
np.random.seed(2022)

# %% [markdown]
# ## Creacion de DataFrames para simulacion de analisis
# De acuerdo a la definicion de variables se crean los dataframes necesarios.
#
# Para facilitar luego la exploracion de datos (EDA) las variables solo tendran valores numericos (aunque representen categorias)

# %% [markdown]
# ### a. Indicador de integración urbano-ambiental
#
# <br>
#
# * Dimensión Urbana:
#
# <br>
#
# |       Nombre             | Variable | Tipo | Dtype | Distribucion|
# |:-------------------------|:---------|-----:|------:|:---:|
# |Accesibilidad (rampas en la vía pública) | **IU_Acce**  | 0 a 2 |float | std|
# |Agua| **IU_Agua**  | bol | bol | Unif.|
# |Cloacas| **IU_Cloa** | bol | bol | Unif.|
# |Corredores seguros|**IU_Corr_segu**| 0 a  2 | float| Std.|
# |Electricidad| **IU_Elec**|1-100 | int| Std.
# |Existencia de espacio público | **IU_Espa_Pub**|0 a 2|float|Std|
# |Existencia de transporte público| **IU_Tran_Pub**|bol|bol|Unif.|
# |Pavimentación de calles| **IU_Nivl_Pavi**|1-100|int|std|
# |(conexión vial, int. a la cuadrícula urbana) Continuidad vial
# |Saneamiento hidráulico|**IU_Sane_Urba**|bol|bol|Unif|
# |Señalización de la vía pública y Forestación|**IU_Sena_y_fore**| 0 a 2 |float|Std|
# |Transitabilidad de la vía publica|**IU_Tran**|1-100|int|Std|
# |Viviendas mejoradas: ambientes | **IU_Vivi_Mejo_Ambi** |0 a 2|float|std|
# |Viviendas mejoradas: características constructivas, problemas|**IU_Vivi_Mejo_Pblm**|0-2|float|std|

# %%
np.random.randn(10)
# Out:
# array([ 1.4120435 ,  0.56970097, -0.62214531, -0.00923052,  0.08697263,
#        -0.92536502, -1.18263854,  0.18237692,  0.60934398,  0.51037677])

# %%
n = 100
df = pd.DataFrame(
    {
        'IU_Acce' : abs(np.random.randn(n)),
        'IU_Agua' : np.random.choice(a=[False, True], size=n),
        'IU_Cloa' : np.random.choice(a=[False, True], size=n),
        'IU_Corr_segu': abs(np.random.randn(n)),
        'IU_Elec': np.round(abs(50 + 50 * np.random.randn(n))),
        'IU_Espa_Pub': abs(np.random.randn(n)),
        'IU_Tran_Pub': np.random.choice(a=[False, True], size=n),
        'IU_Nivl_Pavi': np.round(abs(50 + 50 * np.random.randn(n))),
        'IU_Sane_Urba': np.random.choice(a=[False, True], size=n),
        'IU_Sena_y_fore': abs(np.random.randn(n)),
        'IU_Tran': np.round(abs(50 + 50 * np.random.randn(n))),
        'IU_Vivi_Mejo_Ambi': abs(np.random.randn(n)),
        'IU_Vivi_Mejo_Pblm': abs(np.random.randn(n)),
    }
)
df.head(10)
# Out:
#     IU_Acce  IU_Agua  IU_Cloa  ...  IU_Tran  IU_Vivi_Mejo_Ambi  IU_Vivi_Mejo_Pblm
# 0  0.255302     True    False  ...     82.0           1.109627           0.025275
# 1  0.433378    False    False  ...     86.0           2.018665           1.578665
# 2  0.004722    False    False  ...    117.0           1.282196           0.676553
# 3  0.669604     True    False  ...     64.0           0.903815           0.383413
# 4  1.350397     True     True  ...     93.0           0.541698           0.121923
# 5  0.316099     True     True  ...    105.0           0.321482           1.171076
# 6  0.144891    False    False  ...     48.0           1.575409           1.894445
# 7  0.792834    False    False  ...     46.0           0.945219           1.420148
# 8  0.411862     True    False  ...     69.0           0.071218           1.339256
# 9  0.095789    False     True  ...      4.0           1.047711           0.996234
#
# [10 rows x 13 columns]

# %%
df.shape
# Out:
# (100, 13)

# %% [markdown]
# Algunos registros, cabecera , cola, dimensiones

# %%
df.head()
# Out:
#     IU_Acce  IU_Agua  IU_Cloa  ...  IU_Tran  IU_Vivi_Mejo_Ambi  IU_Vivi_Mejo_Pblm
# 0  0.255302     True    False  ...     82.0           1.109627           0.025275
# 1  0.433378    False    False  ...     86.0           2.018665           1.578665
# 2  0.004722    False    False  ...    117.0           1.282196           0.676553
# 3  0.669604     True    False  ...     64.0           0.903815           0.383413
# 4  1.350397     True     True  ...     93.0           0.541698           0.121923
#
# [5 rows x 13 columns]

# %%
df.tail()
# Out:
#      IU_Acce  IU_Agua  IU_Cloa  ...  IU_Tran  IU_Vivi_Mejo_Ambi  IU_Vivi_Mejo_Pblm
# 95  0.079525     True    False  ...     45.0           0.677995           0.522872
# 96  0.457454     True    False  ...     72.0           0.580273           0.056131
# 97  0.131440     True     True  ...     43.0           0.060938           1.093400
# 98  0.840690    False    False  ...     44.0           0.502763           1.310797
# 99  0.897341    False    False  ...     92.0           0.098392           0.358953
#
# [5 rows x 13 columns]

# %% [markdown]
# Cantidad para cada uno de los valores que toma determinada variable

# %%
# Cantidad de registros para cada valor del "feature" que queremos predecir
df["IU_Cloa"].value_counts()
# Out:
# False    53
# True     47
# Name: IU_Cloa, dtype: int64

# %%
df["IU_Cloa"].value_counts().plot(kind="bar", color=["lightblue", "Salmon"]);
plt.title("Frecuncia de cloacas en los barrios de la Pcia de Buenos Aires")
plt.xlabel("Cloacas,  Sin Cloacas ")
plt.ylabel("Cantidad")
# Out:
# Text(0, 0.5, 'Cantidad')

# %% [markdown]
# Informacion del Data Frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   IU_Acce            100 non-null    float64
#  1   IU_Agua            100 non-null    bool
#  2   IU_Cloa            100 non-null    bool
#  3   IU_Corr_segu       100 non-null    float64
#  4   IU_Elec            100 non-null    float64
#  5   IU_Espa_Pub        100 non-null    float64
#  6   IU_Tran_Pub        100 non-null    bool
#  7   IU_Nivl_Pavi       100 non-null    float64
#  8   IU_Sane_Urba       100 non-null    bool
#  9   IU_Sena_y_fore     100 non-null    float64
#  10  IU_Tran            100 non-null    float64
#  11  IU_Vivi_Mejo_Ambi  100 non-null    float64
#  12  IU_Vivi_Mejo_Pblm  100 non-null    float64
# dtypes: bool(4), float64(9)
# memory usage: 7.5 KB

# %%
# ¿Hay datos faltantes?
df.isna().sum()
# Out:
# IU_Acce              0
# IU_Agua              0
# IU_Cloa              0
# IU_Corr_segu         0
# IU_Elec              0
# IU_Espa_Pub          0
# IU_Tran_Pub          0
# IU_Nivl_Pavi         0
# IU_Sane_Urba         0
# IU_Sena_y_fore       0
# IU_Tran              0
# IU_Vivi_Mejo_Ambi    0
# IU_Vivi_Mejo_Pblm    0
# dtype: int64

# %% [markdown]
# Valores estadisticos del Data Frame

# %%
df.describe()
# Out:
#           IU_Acce  IU_Corr_segu  ...  IU_Vivi_Mejo_Ambi  IU_Vivi_Mejo_Pblm
# count  100.000000    100.000000  ...         100.000000         100.000000
# mean     0.748608      0.800830  ...           0.810503           0.711812
# std      0.653670      0.529537  ...           0.654034           0.522928
# min      0.000925      0.019823  ...           0.025140           0.012108
# 25%      0.264210      0.372317  ...           0.315997           0.270965
# 50%      0.599423      0.728415  ...           0.565713           0.636597
# 75%      1.059140      1.114278  ...           1.225899           1.090033
# max      2.932182      2.505158  ...           2.830215           1.894816
#
# [8 rows x 9 columns]

# %% [markdown]
# ### Frecuencia de Cloacas respecto al agua

# %%
df.IU_Agua.value_counts()
# Out:
# True     52
# False    48
# Name: IU_Agua, dtype: int64

# %%
# comparacion entre las variables Agua  y cloacas
pd.crosstab(df.IU_Agua, df.IU_Cloa)
# Out:
# IU_Cloa  False  True
# IU_Agua
# False       25     23
# True        28     24

# %%
# grafica del crosstab
pd.crosstab(df.IU_Agua, df.IU_Cloa).plot (kind="bar",
                                     figsize=(10, 6),
                                     color=["lightblue", "salmon"])
plt.title("comparacion entre las variables Agua  y cloacas")
plt.xlabel("Falso= sin clacas, verdadero = Con cloacas")
plt.ylabel("Cantidad")
plt.legend(["sin luz", "con luz"])
plt.xticks(rotation=0);

# %% [markdown]
# ### DESPUES SIGOOOOO

# %%
# crear una figura
plt.figure(figsize=(10, 6))

# Dispersión para muestras positivas en agua
plt.scatter(df.IU_Tran[df.IU_Agua==1],
            df.IU_Elec[df.IU_Agua==1],
            c="salmon")
# Dispersión para muestras negastivas en agua
plt.scatter(df.IU_Tran[df.IU_Agua==0],
            df.IU_Elec[df.IU_Agua==0],
            c="lightblue");

# cuztomizing grafico
plt.title("Agua en funcion del transporte y electricidad")
plt.xlabel("Transporte")
plt.ylabel("electricidad")
plt.legend(["Con agua", "Sin agua"]);

# %%
# distribucion de la edad en un histograma
df.IU_Tran.plot.hist();

# %% [markdown]
# ### Frecuencia de Cardiopatia por tipo de Angina<br>
# <b>cp - chest pain type</b>
# <br>
# <br>
# 0- Typical angina: chest pain related decrease blood supply to the heart<br>
# 1- Atypical angina: chest pain not related to heart<br>
# 2- Non-anginal pain: typically esophageal spasms (non heart related)<br>
# 3- Asymptomatic: chest pain not showing signs of disease

# %%
df.head(
)
# Out:
#     IU_Acce  IU_Agua  IU_Cloa  ...  IU_Tran  IU_Vivi_Mejo_Ambi  IU_Vivi_Mejo_Pblm
# 0  0.255302     True    False  ...     82.0           1.109627           0.025275
# 1  0.433378    False    False  ...     86.0           2.018665           1.578665
# 2  0.004722    False    False  ...    117.0           1.282196           0.676553
# 3  0.669604     True    False  ...     64.0           0.903815           0.383413
# 4  1.350397     True     True  ...     93.0           0.541698           0.121923
#
# [5 rows x 13 columns]

# %%
pd.crosstab(df.IU_Tran_Pub, df.IU_Sane_Urba)
# Out:
# IU_Sane_Urba  False  True
# IU_Tran_Pub
# False            25     16
# True             30     29

# %%
# grafica
pd.crosstab(df.IU_Tran_Pub, df.IU_Sane_Urba).plot(kind="bar",
                                   figsize=(10, 6),
                                   color= ["salmon", "lightblue"])
# cuztomizing grafica
plt.title("Frecuencia de Transporte publico por existencia de Saneamiento Urbano")
plt.xlabel("Saneamiento Urbano")
plt.ylabel("Aumento")
plt.legend(["Con Transporte", "Sin Transporte"])
plt.xticks(rotation=0);

# %%
df.head()
# Out:
#     IU_Acce  IU_Agua  IU_Cloa  ...  IU_Tran  IU_Vivi_Mejo_Ambi  IU_Vivi_Mejo_Pblm
# 0  0.255302     True    False  ...     82.0           1.109627           0.025275
# 1  0.433378    False    False  ...     86.0           2.018665           1.578665
# 2  0.004722    False    False  ...    117.0           1.282196           0.676553
# 3  0.669604     True    False  ...     64.0           0.903815           0.383413
# 4  1.350397     True     True  ...     93.0           0.541698           0.121923
#
# [5 rows x 13 columns]

# %%
# Matriz de correlacion
df.corr()
# Out:
#                     IU_Acce   IU_Agua  ...  IU_Vivi_Mejo_Ambi  IU_Vivi_Mejo_Pblm
# IU_Acce            1.000000  0.001119  ...          -0.150691          -0.239802
# IU_Agua            0.001119  1.000000  ...          -0.134149          -0.120396
# IU_Cloa           -0.017001 -0.017646  ...           0.024484           0.059157
# IU_Corr_segu       0.034319 -0.048706  ...          -0.196206           0.109520
# IU_Elec            0.041640 -0.095086  ...           0.022657           0.040148
# IU_Espa_Pub       -0.150121  0.192070  ...          -0.033384          -0.016104
# IU_Tran_Pub       -0.009493  0.053720  ...          -0.114945          -0.139797
# IU_Nivl_Pavi      -0.106417  0.178913  ...          -0.090619          -0.005291
# IU_Sane_Urba      -0.038158 -0.096561  ...           0.106590           0.009012
# IU_Sena_y_fore     0.252961 -0.047714  ...           0.008221          -0.013833
# IU_Tran            0.004163 -0.052929  ...          -0.120318          -0.040690
# ...

# %%
#grafica con heatmap
corr_matrix = df.corr()
fig, ax = plt.subplots(figsize=(15, 10))
ax = sns.heatmap(corr_matrix,
                 annot=True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="YlGnBu");

# %% [markdown]
# ## 5. Modelado

# %%
df.head()
# Out:
#     IU_Acce  IU_Agua  IU_Cloa  ...  IU_Tran  IU_Vivi_Mejo_Ambi  IU_Vivi_Mejo_Pblm
# 0  0.593054     True    False  ...       95           0.664029           0.651144
# 1  1.705604    False    False  ...       65          -1.020798           0.799969
# 2  0.659549    False     True  ...       76          -1.709717           0.469107
# 3  0.970727     True     True  ...       19          -0.166203           0.898280
# 4  0.670992    False    False  ...       43           3.158026           3.428521
#
# [5 rows x 13 columns]

# %% [markdown]
# ### Comparacion de modelos

# %%
model_compare = pd.DataFrame(model_scores, index=["accuracy"])
model_compare.T.plot.bar();

# %% [markdown]
# Como se puede observar en la grafica de comparacion de modelos. ya tenemos un modelos de base con el que trabajar para mejorar las predicciones
# pasos a seguir:
# 1. Hyperparameters tuning
# 2. Feature importance
# 3. Confusion matrix
# 4. Cross-validation
# 5. Precision
# 6. Recall
# 7. F1 score
# 8. Classification report
# 9. ROC Curve
# 10. Area under the curve (AUC)

# %% [markdown]
# ### Manual Hyperparameter tunning

# %%
# tune KNN
train_scores =[]
test_scores = []

# creamos una lñista de diferentes valores para n_neighbors
neighbors = range(1, 21)

# agregamos la instancia a una variable knn
knn = KNeighborsClassifier()

# pasamos por todos los parametros
for i in neighbors:
    knn.set_params(n_neighbors=i)
    # entrenar el modelo
    knn.fit(X_train, y_train)
    # actualizar la lista de puntajes del entrenamiento
    train_scores.append(knn.score(X_train, y_train))
    # actualizar la lista de puntajes de test
    test_scores.append(knn.score(X_test, y_test))

# %%
plt.plot(neighbors, train_scores, label="Puntaje de entrenamiento")
plt.plot(neighbors, test_scores, label="Puntaje de test")
plt.xticks(np.arange(1, 21, 1))
plt.xlabel("Numero de neighbors")
plt.ylabel("puntaje del modelo")
plt.legend()
print(f"KNN maximo en los datos de testeo: {max(test_scores)*100:.2f}%")
# Out:
# KNN maximo en los datos de testeo: 75.41%

# %% [markdown]
# ### y podes armar el grafico que quieras..

# %%
import numpy as np
import matplotlib.pyplot as plt


fig, (ax1, ax2) = plt.subplots(2, 1)
# make a little extra space between the subplots
fig.subplots_adjust(hspace=0.5)

dt = 0.01
t = np.arange(0, 30, dt)

# Fixing random state for reproducibility
np.random.seed(19680801)


nse1 = np.random.randn(len(t))                 # white noise 1
nse2 = np.random.randn(len(t))                 # white noise 2
r = np.exp(-t / 0.05)

cnse1 = np.convolve(nse1, r, mode='same') * dt   # colored noise 1
cnse2 = np.convolve(nse2, r, mode='same') * dt   # colored noise 2

# two signals with a coherent part and a random part
s1 = 0.01 * np.sin(2 * np.pi * 10 * t) + cnse1
s2 = 0.01 * np.sin(2 * np.pi * 10 * t) + cnse2

ax1.plot(t, s1, t, s2)
ax1.set_xlim(0, 5)
ax1.set_xlabel('time')
ax1.set_ylabel('s1 and s2')
ax1.grid(True)

cxy, f = ax2.csd(s1, s2, 256, 1. / dt)
ax2.set_ylabel('CSD (db)')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 100
r0 = 0.6
x = 0.9 * np.random.rand(N)
y = 0.9 * np.random.rand(N)
area = (20 * np.random.rand(N))**2  # 0 to 10 point radii
c = np.sqrt(area)
r = np.sqrt(x ** 2 + y ** 2)
area1 = np.ma.masked_where(r < r0, area)
area2 = np.ma.masked_where(r >= r0, area)
plt.scatter(x, y, s=area1, marker='^', c=c)
plt.scatter(x, y, s=area2, marker='o', c=c)
# Show the boundary between the regions:
theta = np.arange(0, np.pi / 2, 0.01)
plt.plot(r0 * np.cos(theta), r0 * np.sin(theta))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm

# Default delta is large because that makes it fast, and it illustrates
# the correct registration between image and contours.
delta = 0.5

extent = (-3, 4, -4, 3)

x = np.arange(-3.0, 4.001, delta)
y = np.arange(-4.0, 3.001, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
Z = (Z1 - Z2) * 2

# Boost the upper limit to avoid truncation errors.
levels = np.arange(-2.0, 1.601, 0.4)

norm = cm.colors.Normalize(vmax=abs(Z).max(), vmin=-abs(Z).max())
cmap = cm.PRGn

fig, _axs = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))
fig.subplots_adjust(hspace=0.3)
axs = _axs.flatten()

cset1 = axs[0].contourf(X, Y, Z, levels, norm=norm,
                        cmap=cm.get_cmap(cmap, len(levels) - 1))
# It is not necessary, but for the colormap, we need only the
# number of levels minus 1.  To avoid discretization error, use
# either this number or a large number such as the default (256).

# If we want lines as well as filled regions, we need to call
# contour separately; don't try to change the edgecolor or edgewidth
# of the polygons in the collections returned by contourf.
# Use levels output from previous call to guarantee they are the same.

cset2 = axs[0].contour(X, Y, Z, cset1.levels, colors='k')

# We don't really need dashed contour lines to indicate negative
# regions, so let's turn them off.

for c in cset2.collections:
    c.set_linestyle('solid')

# It is easier here to make a separate call to contour than
# to set up an array of colors and linewidths.
# We are making a thick green line as a zero contour.
# Specify the zero level as a tuple with only 0 in it.

cset3 = axs[0].contour(X, Y, Z, (0,), colors='g', linewidths=2)
axs[0].set_title('Filled contours')
fig.colorbar(cset1, ax=axs[0])


axs[1].imshow(Z, extent=extent, cmap=cmap, norm=norm)
axs[1].contour(Z, levels, colors='k', origin='upper', extent=extent)
axs[1].set_title("Image, origin 'upper'")

axs[2].imshow(Z, origin='lower', extent=extent, cmap=cmap, norm=norm)
axs[2].contour(Z, levels, colors='k', origin='lower', extent=extent)
axs[2].set_title("Image, origin 'lower'")

# We will use the interpolation "nearest" here to show the actual
# image pixels.
# Note that the contour lines don't extend to the edge of the box.
# This is intentional. The Z values are defined at the center of each
# image pixel (each color block on the following subplot), so the
# domain that is contoured does not extend beyond these pixel centers.
im = axs[3].imshow(Z, interpolation='nearest', extent=extent,
                   cmap=cmap, norm=norm)
axs[3].contour(Z, levels, colors='k', origin='image', extent=extent)
ylim = axs[3].get_ylim()
axs[3].set_ylim(ylim[::-1])
axs[3].set_title("Origin from rc, reversed y-axis")
fig.colorbar(im, ax=axs[3])

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Random test data
np.random.seed(19680801)
all_data = [np.random.normal(0, std, size=100) for std in range(1, 4)]
labels = ['x1', 'x2', 'x3']

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 8))

# rectangular box plot
bplot1 = ax1.boxplot(all_data,
                     vert=True,  # vertical box alignment
                     patch_artist=True,  # fill with color
                     labels=labels)  # will be used to label x-ticks
ax1.set_title('Rectangular box plot')

# notch shape box plot
bplot2 = ax2.boxplot(all_data,
                     notch=True,  # notch shape
                     vert=True,  # vertical box alignment
                     patch_artist=True,  # fill with color
                     labels=labels)  # will be used to label x-ticks
ax2.set_title('Notched box plot')

# fill with colors
colors = ['pink', 'lightblue', 'lightgreen']
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

# adding horizontal grid lines
for ax in [ax1, ax2]:
    ax.yaxis.grid(True)
    ax.set_xlabel('Three separate samples')
    ax.set_ylabel('Observed values')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import ConnectionPatch
import numpy as np

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
ratios = [.27, .56, .17]
labels = ['Approve', 'Disapprove', 'Undecided']
explode = [0.1, 0, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * ratios[0]
ax1.pie(ratios, autopct='%1.1f%%', startangle=angle,
        labels=labels, explode=explode)

# bar chart parameters

xpos = 0
bottom = 0
ratios = [.33, .54, .07, .06]
width = .2
colors = [[.1, .3, .5], [.1, .3, .3], [.1, .3, .7], [.1, .3, .9]]

for j in range(len(ratios)):
    height = ratios[j]
    ax2.bar(xpos, height, width, bottom=bottom, color=colors[j])
    ypos = bottom + ax2.patches[j].get_height() / 2
    bottom += height
    ax2.text(xpos, ypos, "%d%%" % (ax2.patches[j].get_height() * 100),
             ha='center')

ax2.set_title('Age of approvers')
ax2.legend(('50-65', 'Over 65', '35-49', 'Under 35'))
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
# get the wedge data
theta1, theta2 = ax1.patches[0].theta1, ax1.patches[0].theta2
center, r = ax1.patches[0].center, ax1.patches[0].r
bar_height = sum([item.get_height() for item in ax2.patches])

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(projection='3d')
x, y = np.random.rand(2, 100) * 4
hist, xedges, yedges = np.histogram2d(x, y, bins=4, range=[[0, 4], [0, 4]])

# Construct arrays for the anchor positions of the 16 bars.
xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25, indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0

# Construct arrays with the dimensions for the 16 bars.
dx = dy = 0.5 * np.ones_like(zpos)
dz = hist.ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

ax = plt.figure(figsize=(12,10)).add_subplot(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)

# Plot the 3D surface
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)

# Plot projections of the contours for each dimension.  By choosing offsets
# that match the appropriate axes limits, the projected contours will sit on
# the 'walls' of the graph
cset = ax.contourf(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlim(-40, 40)
ax.set_ylim(-40, 40)
ax.set_zlim(-100, 100)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
